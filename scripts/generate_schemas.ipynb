# %%
# !git clone https://github.com/NickCrews/fech-sources
# !cd fech-sources && git checkout 781671732c5ffd411d374cdb46401c28ff761507 && cd ..
# Out:
# Cloning into 'fech-sources'...
# remote: Enumerating objects: 373, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 373 (delta 72), reused 114 (delta 62), pack-reused 219
# Receiving objects: 100% (373/373), 194.15 KiB | 1.64 MiB/s, done.
# Resolving deltas: 100% (208/208), done.
# Note: switching to '781671732c5ffd411d374cdb46401c28ff761507'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 7816717 Fix F57.csv

# %%
from pathlib import Path
import json

import csv
from typing import NamedTuple

from collections import Counter

csvs = Path("fech-sources/").glob("*.csv")
csvs = list(csvs)
print(f"Found {len(csvs)} CSVs")
csvs[:5]
# Out:
# Found 58 CSVs
# [PosixPath('fech-sources/F3Z2.csv'),
#  PosixPath('fech-sources/F76.csv'),
#  PosixPath('fech-sources/F3Z1.csv'),
#  PosixPath('fech-sources/F99.csv'),
#  PosixPath('fech-sources/TEXT.csv')]

# %%
class Field(NamedTuple):
    # The canonical name of the field
    canonical_name: str
    # The raw name of the field in the CSV
    name_raw: str


VersionPattern = str
Schema = list[Field]


def make_schema_lookup(p: Path) -> dict[VersionPattern, Schema]:
    """Load a CSV into a lookup table form version -> schema."""
    p = Path(p)
    r = csv.reader(open(p))

    # See for an example https://github.com/dwillis/fech-sources/blob/master/F3.csv
    # The file looks like:
    #
    # canonical,^8.4|8.3|8.2|8.1|8.0|7.0|6.4,,^6.3|6.2|6.1,,^5.3|5.2|5.1|5.0,,^3.0,
    # form_type,1,FORM TYPE,1,FORM TYPE,1,FORM TYPE,1,FORM TYPE
    # filer_committee_id_number,2,FILER COMMITTEE ID NUMBER,2,FILER COMMITTEE ID NUMBER,2,FILER COMMITTEE ID NUMBER,2,FILER COMMITTEE ID NUMBER
    # committee_name,3,COMMITTEE NAME,3,COMMITTEE NAME,3,COMMITTEE NAME,3,COMMITTEE NAME
    # change_of_address,4,CHANGE OF ADDRESS,4,CHANGE OF ADDRESS,9,CHG OF ADDRESS,9,CHG OF ADDRESS
    #
    # Where the first columns is the canonical name of the field, and the rest are
    # regexes that match the filing versions
    first_row = next(r)
    # Every other column, starting with the second, is a regex
    patterns = first_row[1::2]

    pattern_to_fields = {p: [] for p in patterns}
    for i, row in enumerate(r):
        # First column is the canonical name for that field
        # Then the rest of the columns are pairs, one for each pattern:
        # The first element of each pair is the column position in the source file,
        # and the second is name of the field for that version of the form.
        canonical_name = row[0]
        positions = row[1::2]
        names = row[2::2]
        if len(positions) != len(patterns):
            raise ValueError(
                f"Expected {len(patterns)} positions, but found {positions} in row {i}"
            )
        if len(names) != len(patterns):
            raise ValueError(
                f"Expected {len(patterns)} names, but found {names} in row {i}"
            )
        for pattern, pos, name in zip(patterns, positions, names, strict=True):
            if not pos:
                # This field doesn't exist in this version of the form
                continue
            try:
                p = int(pos)
            except ValueError:
                raise ValueError(f"Expected a position, but found {pos} in row {i}")
            pattern_to_fields[pattern].append((p, canonical_name.strip(), name.strip()))

    result = {}
    for pattern, fields in pattern_to_fields.items():
        try:
            s = _sort_fields(fields)
        except ValueError as e:
            raise ValueError(f"Error in fields for pattern {pattern}") from e
        result[pattern] = s
    return result


def _sort_fields(fields: list[tuple]):
    s = sorted(fields, key=lambda x: x[0])
    positions = [pos for pos, canonical_name, name in s]
    # expected = list(range(len(positions)))
    # if positions != expected:
    #     print(s)
    #     print(positions)
    #     print(expected)
    #     print(set(positions) - set(expected))
    #     print(set(expected) - set(positions))
    #     raise ValueError("Positions are not sequential")
    c = Counter(positions)
    for pos, count in c.items():
        if count > 1:
            raise ValueError(f"Position {pos} has {count} appearances")

    s = [(canonical_name, name) for pos, canonical_name, name in s]
    return s

# %%
form_name_to_schemas = {}
for i, p in enumerate(csvs):
    print(f"Loading {i}/{len(csvs)}")
    form_name = p.stem
    try:
        lookup = make_schema_lookup(p)
    except ValueError as e:
        raise ValueError(f"Error parsing {p}") from e
    form_name_to_schemas[form_name] = lookup

form_name_to_schemas
# Out:
# Loading 0/58
# Loading 1/58
# Loading 2/58
# Loading 3/58
# Loading 4/58
# Loading 5/58
# Loading 6/58
# Loading 7/58
# Loading 8/58
# Loading 9/58
# Loading 10/58
# Loading 11/58
# Loading 12/58
# Loading 13/58
# Loading 14/58
# Loading 15/58
# Loading 16/58
# Loading 17/58
# Loading 18/58
# Loading 19/58
# Loading 20/58
# Loading 21/58
# Loading 22/58
# Loading 23/58
# Loading 24/58
# Loading 25/58
# Loading 26/58
# Loading 27/58
# Loading 28/58
# Loading 29/58
# Loading 30/58
# Loading 31/58
# Loading 32/58
# Loading 33/58
# Loading 34/58
# Loading 35/58
# Loading 36/58
# Loading 37/58
# Loading 38/58
# Loading 39/58
# Loading 40/58
# Loading 41/58
# Loading 42/58
# Loading 43/58
# Loading 44/58
# Loading 45/58
# Loading 46/58
# Loading 47/58
# Loading 48/58
# Loading 49/58
# Loading 50/58
# Loading 51/58
# Loading 52/58
# Loading 53/58
# Loading 54/58
# Loading 55/58
# Loading 56/58
# Loading 57/58
# {'F3Z2': {'^8.4|8.3|8.2': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('principal_committee_name', 'PRINCIPAL COMMITTEE NAME'),
#    ('coverage_from_date', 'COVERAGE FROM DATE'),
#    ('coverage_through_date', 'COVERAGE THROUGH DATE'),
#    ('col_a_net_contributions', '6(c) Net Contributions'),
#    ('col_a_net_operating_expenditures', '7(c) Net Operating Expenditures'),
#    ('col_a_debts_to', '9 Debts and Obligations Owed TO the Committee'),
#    ('col_a_debts_by', '10 Debts and Obligations Owed BY the Committee'),
#    ('col_a_individual_contributions',
#     '11(a) Contributions from Individuals/Persons Other Than Political Committees'),
#    ('col_a_political_party_contributions',
#     '11(b) Contributions from Political Party Committees'),
#    ('col_a_pac_contributions',
#     '11(c) Contributions from Other Political Committees'),
#    ('col_a_candidate_contributions', '11(d) Contributions from the Candidate'),
#    ('col_a_total_contributions', '11(e) Total Contributions'),
#    ('col_a_transfers_from_authorized',
#     '12 Transfers from Other Authorized Committees'),
#    ('col_a_candidate_loans',
#     '13(a) Loans Made or Guaranteed by the Candidate'),
#    ('col_a_other_loans', '13(b) All Other Loans'),
#    ('col_a_total_loans', '13(c) Total Loans'),
#    ('col_a_offset_to_operating_expenditures',
#     '14 Offsets to Operating Expenditures'),
#    ('col_a_other_receipts', '15 Other Receipts'),
#    ('col_a_total_receipts', '16 Total Receipts'),
#    ('col_a_operating_expenditures', '17 Operating Expenditures'),
#    ('col_a_transfers_to_authorized',
#     '18 Transfers to Other Authorized Committees'),
#    ('col_a_loan_repayments_by_candidate',
#     '19(a) Repayments of Loans Made or Guaranteed by Candidate'),
#    ('col_a_loan_repayments_other', '19(b) Other Loan Repayments'),
#    ('col_a_loan_repayments_total', '19(c) Total Loan Repayments'),
#    ('col_a_refunds_individuals',
#     '20(a) Refunds of Contributions to Individuals/Persons'),
#    ('col_a_refunds_parties',
#     '20(b) Refunds of Contributions to Political Party Committees'),
#    ('col_a_refunds_pacs',
#     '20(c) Refunds of Contributions to Other Political Committees'),
#    ('col_a_refunds_total', '20(d) Total Contributions Refunds'),
#    ('col_a_other_disbursements', '21 Other Disbursements'),
#    ('col_a_total_disbursements', '22 Total Disbursements'),
#    ('col_a_cash_beginning_reporting_period',
#     '23 Cash on Hand at Beginning of Reporting Period'),
#    ('col_a_cash_on_hand_close',
#     '27 Cash on Hand at Close of Reporting Period')]},
#  'F76': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id', 'TRANSACTION ID NUMBER'),
#    ('communication_type', 'COMMUNICATION TYPE'),
#    ('communication_type_description',
#     'COMMUNICATION TYPE - OTHER DESCRIPTION'),
#    ('communication_class', 'COMMUNICATION CLASS'),
#    ('communication_date', 'COMMUNICATION DATE'),
#    ('communication_cost', 'COMMUNICATION COST (per candidate)'),
#    ('election_code', 'ELECTION CODE'),
#    ('election_other_description', 'ELECTION OTHER DESCRIPTION'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE'),
#    ('candidate_id_number', 'S/O CANDIDATE ID NUMBER'),
#    ('candidate_last_name', 'S/O CANDIDATE LAST NAME'),
#    ('candidate_first_name', 'S/O CANDIDATE FIRST NAME'),
#    ('candidate_middle_name', 'S/O CANDIDATE MIDDLE NAME'),
#    ('candidate_prefix', 'S/O CANDIDATE PREFIX'),
#    ('candidate_suffix', 'S/O CANDIDATE SUFFIX'),
#    ('candidate_office', 'S/O CANDIDATE OFFICE'),
#    ('candidate_state', 'S/O CANDIDATE STATE'),
#    ('candidate_district', 'S/O CANDIDATE DISTRICT')],
#   '^5.3|5.2|5.1|5.0|3.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('communication_type', 'COMMUNICATION TYPE'),
#    ('communication_type_description', 'TRANSDESC (Comm. Descrip)'),
#    ('communication_class', 'COMMUNICATION CLASS'),
#    ('communication_date', 'DATE  (Of Communication)'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE'),
#    ('candidate_id_number', 'FEC CANDIDATE ID NUMBER'),
#    ('candidate_name', 'CANDIDATE NAME'),
#    ('candidate_office', 'CAN/OFFICE'),
#    ('candidate_state', 'CAN/STATE'),
#    ('candidate_district', 'CAN/DIST'),
#    ('election_code', 'RPTPGI'),
#    ('communication_cost', 'COST OF COMMUNICATION'),
#    ('transaction_id', 'TRAN ID')]},
#  'F3Z1': {'^8.4|8.3|8.2': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('principal_committee_name', 'PRINCIPAL COMMITTEE NAME'),
#    ('coverage_from_date', 'COVERAGE FROM DATE'),
#    ('coverage_through_date', 'COVERAGE THROUGH DATE'),
#    ('authorized_committee_id_number', 'AUTHORIZED COMMITTEE ID NUMBER'),
#    ('authorized_committee_name', 'AUTHORIZED COMMITTEE NAME'),
#    ('col_a_net_contributions', '6(c) Net Contributions'),
#    ('col_a_net_operating_expenditures', '7(c) Net Operating Expenditures'),
#    ('col_a_debts_to', '9 Debts and Obligations Owed TO the Committee'),
#    ('col_a_debts_by', '10 Debts and Obligations Owed BY the Committee'),
#    ('col_a_individual_contributions',
#     '11(a) Contributions from Individuals/Persons Other Than Political Committees'),
#    ('col_a_political_party_contributions',
#     '11(b) Contributions from Political Party Committees'),
#    ('col_a_pac_contributions',
#     '11(c) Contributions from Other Political Committees'),
#    ('col_a_candidate_contributions', '11(d) Contributions from the Candidate'),
#    ('col_a_total_contributions', '11(e) Total Contributions'),
#    ('col_a_transfers_from_authorized',
#     '12 Transfers from Other Authorized Committees'),
#    ('col_a_candidate_loans',
#     '13(a) Loans Made or Guaranteed by the Candidate'),
#    ('col_a_other_loans', '13(b) All Other Loans'),
#    ('col_a_total_loans', '13(c) Total Loans'),
#    ('col_a_offset_to_operating_expenditures',
#     '14 Offsets to Operating Expenditures'),
#    ('col_a_other_receipts', '15 Other Receipts'),
#    ('col_a_total_receipts', '16 Total Receipts'),
#    ('col_a_operating_expenditures', '17 Operating Expenditures'),
#    ('col_a_transfers_to_authorized',
#     '18 Transfers to Other Authorized Committees'),
#    ('col_a_loan_repayments_by_candidate',
#     '19(a) Repayments of Loans Made or Guaranteed by Candidate'),
#    ('col_a_loan_repayments_other', '19(b) Other Loan Repayments'),
#    ('col_a_loan_repayments_total', '19(c) Total Loan Repayments'),
#    ('col_a_refunds_individuals',
#     '20(a) Refunds of Contributions to Individuals/Persons'),
#    ('col_a_refunds_parties',
#     '20(b) Refunds of Contributions to Political Party Committees'),
#    ('col_a_refunds_pacs',
#     '20(c) Refunds of Contributions to Other Political Committees'),
#    ('col_a_refunds_total', '20(d) Total Contributions Refunds'),
#    ('col_a_other_disbursements', '21 Other Disbursements'),
#    ('col_a_total_disbursements', '22 Total Disbursements'),
#    ('col_a_cash_beginning_reporting_period',
#     '23 Cash on Hand at Beginning of Reporting Period'),
#    ('col_a_cash_on_hand_close',
#     '27 Cash on Hand at Close of Reporting Period')]},
#  'F99': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('committee_name', 'COMMITTEE NAME'),
#    ('street_1', 'STREET  1'),
#    ('street_2', 'STREET  2'),
#    ('city', 'CITY'),
#    ('state', 'STATE'),
#    ('zip_code', 'ZIP'),
#    ('treasurer_last_name', 'TREASURER LAST NAME'),
#    ('treasurer_first_name', 'TREASURER FIRST NAME'),
#    ('treasurer_middle_name', 'TREASURER MIDDLE NAME'),
#    ('treasurer_prefix', 'TREASURER PREFIX'),
#    ('treasurer_suffix', 'TREASURER SUFFIX'),
#    ('date_signed', 'DATE SIGNED'),
#    ('text_code', 'TEXT CODE'),
#    ('text', 'TEXT')],
#   '^5.3|5.2|5.1|5.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('committee_name', 'COMMITTEE NAME'),
#    ('street_1', 'STREET  1'),
#    ('street_2', 'STREET  2'),
#    ('city', 'CITY'),
#    ('state', 'STATE'),
#    ('zip_code', 'ZIP'),
#    ('treasurer_name', 'NAME/TREASURER (as signed)'),
#    ('date_signed', 'DATE (Signed)'),
#    ('text_code', 'TEXT CODE'),
#    ('text', 'TEXT')],
#   '^3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('committee_name', 'COMMITTEE NAME'),
#    ('street_1', 'STREET  1'),
#    ('street_2', 'STREET  2'),
#    ('city', 'CITY'),
#    ('state', 'STATE'),
#    ('zip_code', 'ZIP'),
#    ('treasurer_name', 'NAME/TREASURER (as signed)'),
#    ('date_signed', 'DATE (Signed)'),
#    ('text', 'TEXT')]},
#  'TEXT': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('rec_type',
#     'REC TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_form_name', 'BACK REFERENCE SCHED / FORM NAME'),
#    ('text', 'TEXT4000')],
#   '^5.3': [('rec_type', 'REC TYPE'),
#    ('form_type', 'FORM TYPE'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('text', 'TEXT4000')],
#   '^5.2|5.1|5.0': [('rec_type', 'REC TYPE'),
#    ('form_type', 'FORM TYPE'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('text', 'TEXT4000')],
#   '^3': [('rec_type', 'REC TYPE'),
#    ('form_type', 'FORM TYPE'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('text', 'TEXT4000')]},
#  'F65': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id', 'TRANSACTION ID NUMBER'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('contributor_organization_name', 'CONTRIBUTOR ORGANIZATION NAME'),
#    ('contributor_last_name', 'CONTRIBUTOR LAST NAME'),
#    ('contributor_first_name', 'CONTRIBUTOR FIRST NAME'),
#    ('contributor_middle_name', 'CONTRIBUTOR MIDDLE NAME'),
#    ('contributor_prefix', 'CONTRIBUTOR PREFIX'),
#    ('contributor_suffix', 'CONTRIBUTOR SUFFIX'),
#    ('contributor_street_1', 'CONTRIBUTOR STREET 1'),
#    ('contributor_street_2', 'CONTRIBUTOR STREET 2'),
#    ('contributor_city', 'CONTRIBUTOR CITY'),
#    ('contributor_state', 'CONTRIBUTOR STATE'),
#    ('contributor_zip_code', 'CONTRIBUTOR ZIP'),
#    ('contributor_fec_id', 'CONTRIBUTOR COMMITTEE FEC ID'),
#    ('contribution_date', 'CONTRIBUTION DATE'),
#    ('contribution_amount', 'CONTRIBUTION AMOUNT'),
#    ('contributor_employer', 'CONTRIBUTOR EMPLOYER'),
#    ('contributor_occupation', 'CONTRIBUTOR_OCCUPATION')],
#   '^5.3|5.2|5.1|5.0|3.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('contributor_name', 'NAME (Contributor/Lender)'),
#    ('contributor_street_1', 'STREET 1'),
#    ('contributor_street_2', 'STREET 2'),
#    ('contributor_city', 'CITY'),
#    ('contributor_state', 'STATE'),
#    ('contributor_zip_code', 'ZIP'),
#    ('contributor_employer', 'INDEMP'),
#    ('contributor_occupation', 'INDOCC'),
#    ('contribution_date', 'DATE (Of Contribution)'),
#    ('contribution_amount', 'AMOUNT'),
#    ('contributor_fec_id', 'FEC COMMITTEE ID NUMBER'),
#    ('candidate_id', 'FEC CANDIDATE ID NUMBER'),
#    ('candidate_name', 'CANDIDATE NAME'),
#    ('candidate_office', 'CAN/OFFICE'),
#    ('candidate_state', 'CAN/STATE'),
#    ('candidate_district', 'CAN/DIST'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('transaction_id', 'TRAN ID')]},
#  'HDR': {'^[6-8]': [('record_type', 'Record Type'),
#    ('ef_type', 'EF Type'),
#    ('fec_version', 'FEC Version #'),
#    ('soft_name', 'Soft Name'),
#    ('soft_ver', 'Soft Ver'),
#    ('report_id', 'Rpt ID'),
#    ('report_number', 'Rpt Number'),
#    ('comment', 'HDRcomment')],
#   '^[3-5]': [('record_type', 'Record Type'),
#    ('ef_type', 'EF Type'),
#    ('fec_version', 'FEC Version #'),
#    ('soft_name', 'Soft Name'),
#    ('soft_ver', 'Soft Ver'),
#    ('name_delim', 'Name Delim'),
#    ('report_id', 'Rpt ID'),
#    ('report_number', 'Rpt Number'),
#    ('comment', 'HDRcomment')]},
#  'SchE': {'^8.4|8.3|8.2|8.1': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'PAYEE STREET  1'),
#    ('payee_street_2', 'PAYEE STREET  2'),
#    ('payee_city', 'PAYEE CITY'),
#    ('payee_state', 'PAYEE STATE'),
#    ('payee_zip_code', 'PAYEE ZIP'),
#    ('election_code', 'ELECTION CODE'),
#    ('election_other_description', 'ELECTION OTHER DESCRIPTION'),
#    ('dissemination_date', 'DISSEMINATION DATE'),
#    ('expenditure_amount', 'EXPENDITURE AMOUNT'),
#    ('disbursement_date', 'DISBURSEMENT DATE'),
#    ('calendar_y_t_d_per_election_office',
#     'CALENDAR Y-T-D (per election/office)'),
#    ('expenditure_purpose_descrip', 'EXPENDITURE PURPOSE DESCRIP'),
#    ('category_code', 'CATEGORY CODE'),
#    ('payee_cmtte_fec_id_number', 'PAYEE CMTTE FEC ID NUMBER'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE CODE'),
#    ('candidate_id_number', 'S/O CANDIDATE ID NUMBER'),
#    ('candidate_last_name', 'S/O CANDIDATE LAST NAME'),
#    ('candidate_first_name', 'S/O CANDIDATE FIRST NAME'),
#    ('candidate_middle_name', 'S/O CANDIDATE MIDDLE NAME'),
#    ('candidate_prefix', 'S/O CANDIDATE PREFIX'),
#    ('candidate_suffix', 'S/O CANDIDATE SUFFIX'),
#    ('candidate_office', 'S/O CANDIDATE OFFICE'),
#    ('candidate_district', 'S/O CANDIDATE DISTRICT'),
#    ('candidate_state', 'S/O CANDIDATE STATE'),
#    ('completing_last_name', 'COMPLETING LAST NAME'),
#    ('completing_first_name', 'COMPLETING FIRST NAME'),
#    ('completing_middle_name', 'COMPLETING MIDDLE NAME'),
#    ('completing_prefix', 'COMPLETING PREFIX'),
#    ('completing_suffix', 'COMPLETING SUFFIX'),
#    ('date_signed', 'DATE SIGNED'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text_description', 'MEMO TEXT/DESCRIPTION')],
#   '^8.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'PAYEE STREET  1'),
#    ('payee_street_2', 'PAYEE STREET  2'),
#    ('payee_city', 'PAYEE CITY'),
#    ('payee_state', 'PAYEE STATE'),
#    ('payee_zip_code', 'PAYEE ZIP'),
#    ('election_code', 'ELECTION CODE'),
#    ('election_other_description', 'ELECTION OTHER DESCRIPTION'),
#    ('dissemination_date', 'EXPENDITURE DATE'),
#    ('expenditure_amount', 'EXPENDITURE AMOUNT'),
#    ('calendar_y_t_d_per_election_office',
#     'CALENDAR Y-T-D (per election/office)'),
#    ('expenditure_purpose_descrip', 'EXPENDITURE PURPOSE DESCRIP'),
#    ('category_code', 'CATEGORY CODE'),
#    ('payee_cmtte_fec_id_number', 'PAYEE CMTTE FEC ID NUMBER'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE CODE'),
#    ('candidate_id_number', 'S/O CANDIDATE ID NUMBER'),
#    ('candidate_last_name', 'S/O CANDIDATE LAST NAME'),
#    ('candidate_first_name', 'S/O CANDIDATE FIRST NAME'),
#    ('candidate_middle_name', 'S/O CANDIDATE MIDDLE NAME'),
#    ('candidate_prefix', 'S/O CANDIDATE PREFIX'),
#    ('candidate_suffix', 'S/O CANDIDATE SUFFIX'),
#    ('candidate_office', 'S/O CANDIDATE OFFICE'),
#    ('candidate_state', 'S/O CANDIDATE STATE'),
#    ('candidate_district', 'S/O CANDIDATE DISTRICT'),
#    ('completing_last_name', 'COMPLETING LAST NAME'),
#    ('completing_first_name', 'COMPLETING FIRST NAME'),
#    ('completing_middle_name', 'COMPLETING MIDDLE NAME'),
#    ('completing_prefix', 'COMPLETING PREFIX'),
#    ('completing_suffix', 'COMPLETING SUFFIX'),
#    ('date_signed', 'DATE SIGNED'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text_description', 'MEMO TEXT/DESCRIPTION')],
#   '^7.0|6.4|6.3|6.2|6.1': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'PAYEE STREET  1'),
#    ('payee_street_2', 'PAYEE STREET  2'),
#    ('payee_city', 'PAYEE CITY'),
#    ('payee_state', 'PAYEE STATE'),
#    ('payee_zip_code', 'PAYEE ZIP'),
#    ('election_code', 'ELECTION CODE'),
#    ('election_other_description', 'ELECTION OTHER DESCRIPTION'),
#    ('dissemination_date', 'EXPENDITURE DATE'),
#    ('expenditure_amount', 'EXPENDITURE AMOUNT'),
#    ('calendar_y_t_d_per_election_office',
#     'CALENDAR Y-T-D (per election/office)'),
#    ('expenditure_purpose_code', 'EXPENDITURE PURPOSE CODE'),
#    ('expenditure_purpose_descrip', 'EXPENDITURE PURPOSE DESCRIP'),
#    ('category_code', 'CATEGORY CODE'),
#    ('payee_cmtte_fec_id_number', 'PAYEE CMTTE FEC ID NUMBER'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE CODE'),
#    ('candidate_id_number', 'S/O CANDIDATE ID NUMBER'),
#    ('candidate_last_name', 'S/O CANDIDATE LAST NAME'),
#    ('candidate_first_name', 'S/O CANDIDATE FIRST NAME'),
#    ('candidate_middle_name', 'S/O CANDIDATE MIDDLE NAME'),
#    ('candidate_prefix', 'S/O CANDIDATE PREFIX'),
#    ('candidate_suffix', 'S/O CANDIDATE SUFFIX'),
#    ('candidate_office', 'S/O CANDIDATE OFFICE'),
#    ('candidate_state', 'S/O CANDIDATE STATE'),
#    ('candidate_district', 'S/O CANDIDATE DISTRICT'),
#    ('completing_last_name', 'COMPLETING LAST NAME'),
#    ('completing_first_name', 'COMPLETING FIRST NAME'),
#    ('completing_middle_name', 'COMPLETING MIDDLE NAME'),
#    ('completing_prefix', 'COMPLETING PREFIX'),
#    ('completing_suffix', 'COMPLETING SUFFIX'),
#    ('date_signed', 'DATE SIGNED'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text_description', 'MEMO TEXT/DESCRIPTION')],
#   '^5.3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_name', 'NAME (Payee)'),
#    ('payee_street_1', 'STREET  1'),
#    ('payee_street_2', 'STREET  2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('expenditure_purpose_descrip', 'TRANS {Purpose} DESCRIP'),
#    ('dissemination_date', 'DATE'),
#    ('expenditure_amount', 'AMOUNT EXPENDED'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE'),
#    ('candidate_id_number', 'S/O FEC CAN ID NUMBER'),
#    ('candidate_name', 'S/O CAN/NAME'),
#    ('candidate_office', 'S/O CAN/OFFICE'),
#    ('candidate_state', 'S/O STATE'),
#    ('candidate_district', 'S/O CAN/DIST'),
#    ('payee_cmtte_fec_id_number', 'FEC COMMITTEE ID NUMBER'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('ind_name_as_signed', 'IND/NAME (as signed)'),
#    ('date_signed', 'DATE (Signed)'),
#    ('date_notarized', 'DATE (Notarized)'),
#    ('date_notary_commission_expires', 'DATE (Notary Commission Expires)'),
#    ('ind_name_notary', 'IND/NAME (Notary)'),
#    ('transaction_id_number', 'TRAN ID'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text_description', 'MEMO TEXT'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME'),
#    ('election_code', 'ITEM ELECT CD'),
#    ('election_other_description', 'ITEM ELECT OTHER'),
#    ('category_code', 'CATEGORY CODE'),
#    ('expenditure_purpose_code', 'TRANS CODE'),
#    ('calendar_y_t_d_per_election_office', 'CALENDAR YTD - OFFICE SOUGHT')],
#   '^5.2|5.1|5.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_name', 'NAME (Payee)'),
#    ('payee_street_1', 'STREET  1'),
#    ('payee_street_2', 'STREET  2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('expenditure_purpose_descrip', 'TRANS {Purpose} DESCRIP'),
#    ('dissemination_date', 'DATE'),
#    ('expenditure_amount', 'AMOUNT EXPENDED'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE'),
#    ('candidate_id_number', 'S/O FEC CAN ID NUMBER'),
#    ('candidate_name', 'S/O CAN/NAME'),
#    ('candidate_office', 'S/O CAN/OFFICE'),
#    ('candidate_state', 'S/O STATE'),
#    ('candidate_district', 'S/O CAN/DIST'),
#    ('payee_cmtte_fec_id_number', 'FEC COMMITTEE ID NUMBER'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('ind_name_as_signed', 'IND/NAME (as signed)'),
#    ('date_signed', 'DATE (Signed)'),
#    ('date_notarized', 'DATE (Notarized)'),
#    ('date_notary_commission_expires', 'DATE (Notary Commission Expires)'),
#    ('ind_name_notary', 'IND/NAME (Notary)'),
#    ('transaction_id_number', 'TRAN ID'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text_description', 'MEMO TEXT'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME'),
#    ('election_code', 'ITEM ELECT CD'),
#    ('election_other_description', 'ITEM ELECT OTHER'),
#    ('category_code', 'CATEGORY CODE'),
#    ('expenditure_purpose_code', 'TRANS CODE'),
#    ('calendar_y_t_d_per_election_office', 'CALENDAR YTD - OFFICE SOUGHT')],
#   '^3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_name', 'NAME (Payee)'),
#    ('payee_street_1', 'STREET  1'),
#    ('payee_street_2', 'STREET  2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('expenditure_purpose_descrip', 'TRANSDESC'),
#    ('dissemination_date', 'DATE'),
#    ('expenditure_amount', 'AMOUNT EXPENDED'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE'),
#    ('candidate_id_number', 'S/O FEC CAN ID NUMBER'),
#    ('candidate_name', 'S/O CAN/NAME'),
#    ('candidate_office', 'S/O CAN/OFFICE'),
#    ('candidate_state', 'S/O STATE'),
#    ('candidate_district', 'S/O CAN/DIST'),
#    ('payee_cmtte_fec_id_number', 'FEC COMMITTEE ID NUMBER'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('ind_name_as_signed', 'IND/NAME (as signed)'),
#    ('date_signed', 'DATE (Signed)'),
#    ('date_notarized', 'DATE (Notarized)'),
#    ('date_notary_commission_expires', 'DATE (Notary Commission Expires)'),
#    ('ind_name_notary', 'IND/NAME (Notary)'),
#    ('transaction_id_number', 'TRAN ID'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text_description', 'MEMO TEXT'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME')]},
#  'SchD': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('creditor_organization_name', 'CREDITOR ORGANIZATION NAME'),
#    ('creditor_last_name', 'CREDITOR LAST NAME'),
#    ('creditor_first_name', 'CREDITOR FIRST NAME'),
#    ('creditor_middle_name', 'CREDITOR MIDDLE NAME'),
#    ('creditor_prefix', 'CREDITOR PREFIX'),
#    ('creditor_suffix', 'CREDITOR SUFFIX'),
#    ('creditor_street_1', 'CREDITOR STREET  1'),
#    ('creditor_street_2', 'CREDITOR STREET  2'),
#    ('creditor_city', 'CREDITOR CITY'),
#    ('creditor_state', 'CREDITOR STATE'),
#    ('creditor_zip_code', 'CREDITOR ZIP'),
#    ('purpose_of_debt_or_obligation', 'PURPOSE OF DEBT OR OBLIGATION'),
#    ('beginning_balance_this_period', 'BEGINNING BALANCE (This Period)'),
#    ('incurred_amount_this_period', 'INCURRED AMOUNT (This Period)'),
#    ('payment_amount_this_period', 'PAYMENT AMOUNT (This Period)'),
#    ('balance_at_close_this_period', 'BALANCE AT CLOSE  (This Period)')],
#   '^5.3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('creditor_name', 'NAME (Debtor/Creditor)'),
#    ('creditor_street_1', 'STREET  1'),
#    ('creditor_street_2', 'STREET  2'),
#    ('creditor_city', 'CITY'),
#    ('creditor_state', 'STATE'),
#    ('creditor_zip_code', 'ZIP'),
#    ('purpose_of_debt_or_obligation', 'NATURE/PURPOSE DEBT DESCRIPTION'),
#    ('beginning_balance_this_period', 'BEGINNING BALANCE'),
#    ('incurred_amount_this_period', 'INCURRED THIS PERIOD'),
#    ('payment_amount_this_period', 'PAYMENT THIS PERIOD'),
#    ('balance_at_close_this_period', 'BALANCE AT CLOSE'),
#    ('fec_committee_id_number', 'FEC COMMITTEE ID NUMBER'),
#    ('fec_candidate_id_number', 'FEC CANDIDATE ID NUMBER'),
#    ('candidate_name', 'CANDIDATE NAME'),
#    ('candidate_office', 'CAN/OFFICE'),
#    ('candidate_state', 'CAN/STATE'),
#    ('candidate_district', 'CAN/DIST'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('transaction_id_number', 'TRAN ID')],
#   '^5.2|5.1|5.0|3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('creditor_name', 'NAME (Debtor/Creditor)'),
#    ('creditor_street_1', 'STREET  1'),
#    ('creditor_street_2', 'STREET  2'),
#    ('creditor_city', 'CITY'),
#    ('creditor_state', 'STATE'),
#    ('creditor_zip_code', 'ZIP'),
#    ('purpose_of_debt_or_obligation', 'NATURE/PURPOSE DEBT DESCRIPTION'),
#    ('beginning_balance_this_period', 'BEGINNING BALANCE'),
#    ('incurred_amount_this_period', 'INCURRED THIS PERIOD'),
#    ('payment_amount_this_period', 'PAYMENT THIS PERIOD'),
#    ('balance_at_close_this_period', 'BALANCE AT CLOSE'),
#    ('fec_committee_id_number', 'FEC COMMITTEE ID NUMBER'),
#    ('fec_candidate_id_number', 'FEC CANDIDATE ID NUMBER'),
#    ('candidate_name', 'CANDIDATE NAME'),
#    ('candidate_office', 'CAN/OFFICE'),
#    ('candidate_state', 'CAN/STATE'),
#    ('candidate_district', 'CAN/DIST'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('transaction_id_number', 'TRAN ID')]},
#  'H6': {'^8.4|8.3|8.2|8.1|8.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'PAYEE STREET  1'),
#    ('payee_street_2', 'PAYEE STREET  2'),
#    ('payee_city', 'PAYEE CITY'),
#    ('payee_state', 'PAYEE STATE'),
#    ('payee_zip_code', 'PAYEE ZIP'),
#    ('account_identifier', 'ACCOUNT/EVENT IDENTIFIER'),
#    ('expenditure_date', 'EXPENDITURE DATE'),
#    ('total_amount', 'TOTAL FED-LEVIN AMOUNT'),
#    ('federal_share', 'FEDERAL SHARE'),
#    ('levin_share', 'LEVIN SHARE'),
#    ('event_year_to_date', 'ACTIVITY/EVENT TOTAL YTD'),
#    ('expenditure_purpose_description', 'EXPENDITURE PURPOSE DESCRIP'),
#    ('category_code', 'CATEGORY CODE'),
#    ('voter_registration_activity', 'YES/NO  (Activity Is Voter Registration)'),
#    ('gotv_activity', 'YES/NO  (Activity GOTV)'),
#    ('voter_id_activity', 'YES/NO  (Activity Is Voter ID)'),
#    ('generic_campaign_activity', 'YES/NO  (Activity is Generic Campaign)'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text', 'MEMO TEXT/DESCRIPTION')],
#   '^7.0|6.4|6.3|6.2|6.1': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'PAYEE STREET  1'),
#    ('payee_street_2', 'PAYEE STREET  2'),
#    ('payee_city', 'PAYEE CITY'),
#    ('payee_state', 'PAYEE STATE'),
#    ('payee_zip_code', 'PAYEE ZIP'),
#    ('account_identifier', 'ACCOUNT/EVENT IDENTIFIER'),
#    ('expenditure_date', 'EXPENDITURE DATE'),
#    ('total_amount', 'TOTAL FED-LEVIN AMOUNT'),
#    ('federal_share', 'FEDERAL SHARE'),
#    ('levin_share', 'LEVIN SHARE'),
#    ('event_year_to_date', 'ACTIVITY/EVENT TOTAL YTD'),
#    ('expenditure_purpose_code', 'EXPENDITURE PURPOSE CODE'),
#    ('expenditure_purpose_description', 'EXPENDITURE PURPOSE DESCRIP'),
#    ('category_code', 'CATEGORY CODE'),
#    ('voter_registration_activity', 'YES/NO  (Activity Is Voter Registration)'),
#    ('gotv_activity', 'YES/NO  (Activity GOTV)'),
#    ('voter_id_activity', 'YES/NO  (Activity Is Voter ID)'),
#    ('generic_campaign_activity', 'YES/NO  (Activity is Generic Campaign)'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text', 'MEMO TEXT/DESCRIPTION')],
#   '^5.3|5.2|5.1|5.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_name', 'NAME  (Payee)'),
#    ('payee_street_1', 'STREET 1'),
#    ('payee_street_2', 'STREET 2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('category_code', 'CATEGORY CODE'),
#    ('expenditure_purpose_code', 'TRANS CODE'),
#    ('expenditure_purpose_description', 'TRANS {Purpose} DESCRIP'),
#    ('expenditure_date', 'DATE'),
#    ('total_amount', 'TOTAL AMOUNT'),
#    ('federal_share', 'FEDERAL SHARE'),
#    ('levin_share', 'LEVIN SHARE'),
#    ('voter_registration_activity', 'YESNO  (Activity Is Voter Registration)'),
#    ('gotv_activity', 'YESNO  (Activity Is Voter ID)'),
#    ('voter_id_activity', 'YESNO  (Activity GOTV)'),
#    ('generic_campaign_activity', 'YESNO  (Activity is Generic Campaign)'),
#    ('event_year_to_date', 'ACTIVITY/EVENT YEAR-TO-DATE'),
#    ('account_identifier', 'ADDITIONAL DESCRIPTION'),
#    ('fec_committee_id_number', 'FEC COMMITTEE ID NUMBER'),
#    ('fec_candidate_id_number', 'FEC CANDIDATE ID NUMBER'),
#    ('candidate_name', 'CANDIDATE NAME'),
#    ('candidate_office', 'CAN/OFFICE'),
#    ('candidate_state', 'CAN/STATE'),
#    ('candidate_district', 'CAN/DIST'),
#    ('conduit_committee_id', 'CONDUIT COMMITTEE ID'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text', 'MEMO TEXT'),
#    ('transaction_id_number', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME')]},
#  'F3PS': {'^8.4|8.3|8.2|8.1|8.0|7.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('date_general_election', 'Date - General Election'),
#    ('date_day_after_general_election', 'Date - Day after General Election'),
#    ('14_net_contributions', '14. Net Contributions'),
#    ('15_net_expenditures', '15. Net Expenditures'),
#    ('16_federal_funds', '16. Federal Funds'),
#    ('17_a_i_individual_contributions_itemized',
#     '17(a.i) Individuals Itemized'),
#    ('17_a_ii_individual_contributions_unitemized',
#     '17(a.ii) Individuals Unitemized'),
#    ('17_a_iii_individual_contributions_total',
#     '17(a.iii) Individual Contribution Total'),
#    ('17_b_political_party_committees', '17(b) Political Party Committees'),
#    ('17_c_other_political_committees_pacs',
#     '17(c) Other Political Committees (PACs)'),
#    ('17_d_the_candidate', '17(d) The Candidate'),
#    ('17_e_total_contributions_other_than_loans',
#     '17(e) Total contributions  (Other than Loans)'),
#    ('18_transfers_from_aff_other_party_committees',
#     '18. Transfers From Aff/Other Party Committees'),
#    ('19_a_received_from_or_guaranteed_by_candidate',
#     '19(a) Received from or Guaranteed  by Candidate'),
#    ('19_b_other_loans', '19(b) Other Loans'),
#    ('19_c_total_loans', '19(c) Total Loans'),
#    ('20_a_operating', '20(a) Operating'),
#    ('20_b_fundraising', '20(b) Fundraising'),
#    ('20_c_legal_and_accounting', '20(c) Legal and Accounting'),
#    ('20_d_total_offsets_to_operating_expenditures',
#     '20(d) Total Offsets to Operating Expenditures'),
#    ('21_other_receipts', '21. Other Receipts'),
#    ('22_total_receipts', '22. Total Receipts'),
#    ('23_operating_expenditures', '23. Operating Expenditures'),
#    ('24_transfers_to_other_authorized_committees',
#     '24. Transfers to Other Authorized Committees'),
#    ('25_fundraising_disbursements', '25. Fundraising Disbursements'),
#    ('26_exempt_legal_and_accounting_disbursements',
#     '26. Exempt Legal and Accounting Disbursements'),
#    ('27_a_loan_repayments_by_candidate',
#     '27(a) Made or Guaranteed by the Candidate'),
#    ('27_b_loan_repayments_other', '27(b) Other Repayments'),
#    ('27_c_loan_repayments_total_made', '27(c) Total Loan Repayments Made'),
#    ('28_a_refunds_individuals', '28(a)  Individuals'),
#    ('28_b_refunds_parties', '28(b) Political Party Committees'),
#    ('28_c_refunds_pacs', '28(c) Other Political Committees'),
#    ('28_d_refunds_total', '28(d) Total Contributions Refunds'),
#    ('29_other_disbursements', '29. Other Disbursements'),
#    ('30_total_disbursements', '30. Total Disbursements'),
#    ('alabama', 'ALABAMA'),
#    ('alaska', 'ALASKA'),
#    ('arizona', 'ARIZONA'),
#    ('arkansas', 'ARKANSAS'),
#    ('california', 'CALIFORNIA'),
#    ('colorado', 'COLORADO'),
#    ('connecticut', 'CONNECTICUT'),
#    ('delaware', 'DELAWARE'),
#    ('dist_of_columbia', 'DIST OF COLUMBIA'),
#    ('florida', 'FLORIDA'),
#    ('georgia', 'GEORGIA'),
#    ('hawaii', 'HAWAII'),
#    ('idaho', 'IDAHO'),
#    ('illinois', 'ILLINOIS'),
#    ('indiana', 'INDIANA'),
#    ('iowa', 'IOWA'),
#    ('kansas', 'KANSAS'),
#    ('kentucky', 'KENTUCKY'),
#    ('louisiana', 'LOUISIANA'),
#    ('maine', 'MAINE'),
#    ('maryland', 'MARYLAND'),
#    ('massachusetts', 'MASSACHUSETTS'),
#    ('michigan', 'MICHIGAN'),
#    ('minnesota', 'MINNESOTA'),
#    ('mississippi', 'MISSISSIPPI'),
#    ('missouri', 'MISSOURI'),
#    ('montana', 'MONTANA'),
#    ('nebraska', 'NEBRASKA'),
#    ('nevada', 'NEVADA'),
#    ('new_hampshire', 'NEW HAMPSHIRE'),
#    ('new_jersey', 'NEW JERSEY'),
#    ('new_mexico', 'NEW MEXICO'),
#    ('new_york', 'NEW YORK'),
#    ('north_carolina', 'NORTH CAROLINA'),
#    ('north_dakota', 'NORTH DAKOTA'),
#    ('ohio', 'OHIO'),
#    ('oklahoma', 'OKLAHOMA'),
#    ('oregon', 'OREGON'),
#    ('pennsylvania', 'PENNSYLVANIA'),
#    ('rhode_island', 'RHODE ISLAND'),
#    ('south_carolina', 'SOUTH CAROLINA'),
#    ('south_dakota', 'SOUTH DAKOTA'),
#    ('tennessee', 'TENNESSEE'),
#    ('texas', 'TEXAS'),
#    ('utah', 'UTAH'),
#    ('vermont', 'VERMONT'),
#    ('virginia', 'VIRGINIA'),
#    ('washington', 'WASHINGTON'),
#    ('west_virginia', 'WEST VIRGINIA'),
#    ('wisconsin', 'WISCONSIN'),
#    ('wyoming', 'WYOMING'),
#    ('puerto_rico', 'PUERTO RICO'),
#    ('guam', 'GUAM'),
#    ('virgin_islands', 'VIRGIN ISLANDS'),
#    ('totals', 'TOTALS')],
#   '^6.4|6.3|6.2|6.1': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('date_general_election', 'Date - General Election'),
#    ('date_day_after_general_election', 'Date - Day after General Election'),
#    ('14_net_contributions', '14. Net Contributions'),
#    ('15_net_expenditures', '15. Net Expenditures'),
#    ('16_federal_funds', '16. Federal Funds'),
#    ('17_a_individuals', '17(a)  Individuals'),
#    ('17_b_political_party_committees', '17(b) Political Party Committees'),
#    ('17_c_other_political_committees_pacs',
#     '17(c) Other Political Committees (PACs)'),
#    ('17_d_the_candidate', '17(d) The Candidate'),
#    ('17_e_total_contributions_other_than_loans',
#     '17(e) Total contributions  (Other than Loans)'),
#    ('18_transfers_from_aff_other_party_committees',
#     '18. Transfers From Aff/Other Party Committees'),
#    ('19_a_received_from_or_guaranteed_by_candidate',
#     '19(a) Received from or Guaranteed  by Candidate'),
#    ('19_b_other_loans', '19(b) Other Loans'),
#    ('19_c_total_loans', '19(c) Total Loans'),
#    ('20_a_operating', '20(a) Operating'),
#    ('20_b_fundraising', '20(b) Fundraising'),
#    ('20_c_legal_and_accounting', '20(c) Legal and Accounting'),
#    ('20_d_total_offsets_to_operating_expenditures',
#     '20(d) Total Offsets to Operating Expenditures'),
#    ('21_other_receipts', '21. Other Receipts'),
#    ('22_total_receipts', '22. Total Receipts'),
#    ('23_operating_expenditures', '23. Operating Expenditures'),
#    ('24_transfers_to_other_authorized_committees',
#     '24. Transfers to Other Authorized Committees'),
#    ('25_fundraising_disbursements', '25. Fundraising Disbursements'),
#    ('26_exempt_legal_and_accounting_disbursements',
#     '26. Exempt Legal and Accounting Disbursements'),
#    ('27_a_loan_repayments_by_candidate',
#     '27(a) Made or Guaranteed by the Candidate'),
#    ('27_b_loan_repayments_other', '27(b) Other Repayments'),
#    ('27_c_loan_repayments_total_made', '27(c) Total Loan Repayments Made'),
#    ('28_a_refunds_individuals', '28(a)  Individuals'),
#    ('28_b_refunds_parties', '28(b) Political Party Committees'),
#    ('28_c_refunds_pacs', '28(c) Other Political Committees'),
#    ('28_d_refunds_total', '28(d) Total Contributions Refunds'),
#    ('29_other_disbursements', '29. Other Disbursements'),
#    ('30_total_disbursements', '30. Total Disbursements'),
#    ('alabama', 'ALABAMA'),
#    ('alaska', 'ALASKA'),
#    ('arizona', 'ARIZONA'),
#    ('arkansas', 'ARKANSAS'),
#    ('california', 'CALIFORNIA'),
#    ('colorado', 'COLORADO'),
#    ('connecticut', 'CONNECTICUT'),
#    ('delaware', 'DELAWARE'),
#    ('dist_of_columbia', 'DIST OF COLUMBIA'),
#    ('florida', 'FLORIDA'),
#    ('georgia', 'GEORGIA'),
#    ('hawaii', 'HAWAII'),
#    ('idaho', 'IDAHO'),
#    ('illinois', 'ILLINOIS'),
#    ('indiana', 'INDIANA'),
#    ('iowa', 'IOWA'),
#    ('kansas', 'KANSAS'),
#    ('kentucky', 'KENTUCKY'),
#    ('louisiana', 'LOUISIANA'),
#    ('maine', 'MAINE'),
#    ('maryland', 'MARYLAND'),
#    ('massachusetts', 'MASSACHUSETTS'),
#    ('michigan', 'MICHIGAN'),
#    ('minnesota', 'MINNESOTA'),
#    ('mississippi', 'MISSISSIPPI'),
#    ('missouri', 'MISSOURI'),
#    ('montana', 'MONTANA'),
#    ('nebraska', 'NEBRASKA'),
#    ('nevada', 'NEVADA'),
#    ('new_hampshire', 'NEW HAMPSHIRE'),
#    ('new_jersey', 'NEW JERSEY'),
#    ('new_mexico', 'NEW MEXICO'),
#    ('new_york', 'NEW YORK'),
#    ('north_carolina', 'NORTH CAROLINA'),
#    ('north_dakota', 'NORTH DAKOTA'),
#    ('ohio', 'OHIO'),
#    ('oklahoma', 'OKLAHOMA'),
#    ('oregon', 'OREGON'),
#    ('pennsylvania', 'PENNSYLVANIA'),
#    ('rhode_island', 'RHODE ISLAND'),
#    ('south_carolina', 'SOUTH CAROLINA'),
#    ('south_dakota', 'SOUTH DAKOTA'),
#    ('tennessee', 'TENNESSEE'),
#    ('texas', 'TEXAS'),
#    ('utah', 'UTAH'),
#    ('vermont', 'VERMONT'),
#    ('virginia', 'VIRGINIA'),
#    ('washington', 'WASHINGTON'),
#    ('west_virginia', 'WEST VIRGINIA'),
#    ('wisconsin', 'WISCONSIN'),
#    ('wyoming', 'WYOMING'),
#    ('puerto_rico', 'PUERTO RICO'),
#    ('guam', 'GUAM'),
#    ('virgin_islands', 'VIRGIN ISLANDS'),
#    ('totals', 'TOTALS')],
#   '^5.3|5.2|5.1|5.0|3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('14_net_contributions', '14. Net Contributions'),
#    ('15_net_expenditures', '15. Net Expenditures'),
#    ('16_federal_funds', '16. Federal Funds'),
#    ('17_a_individuals', '17(a)  Individuals'),
#    ('17_b_political_party_committees', '17(b) Political Party Committees'),
#    ('17_c_other_political_committees_pacs',
#     '17(c) Other Political Committees (PACs)'),
#    ('17_d_the_candidate', '17(d) The Candidate'),
#    ('17_e_total_contributions_other_than_loans',
#     '17(e) Total contributions  (Other than Loans)'),
#    ('18_transfers_from_aff_other_party_committees',
#     '18. Transfers From Aff/Other Party Committees'),
#    ('19_a_received_from_or_guaranteed_by_candidate',
#     '19(a) Received from or Guaranteed  by Candidate'),
#    ('19_b_other_loans', '19(b) Other Loans'),
#    ('19_c_total_loans', '19(c) Total Loans'),
#    ('20_a_operating', '20(a) Operating'),
#    ('20_b_fundraising', '20(b) Fundraising'),
#    ('20_c_legal_and_accounting', '20(c) Legal and Accounting'),
#    ('20_d_total_offsets_to_operating_expenditures',
#     '20(d) Total Offsets to Operating Expenditures'),
#    ('21_other_receipts', '21. Other Receipts'),
#    ('22_total_receipts', '22. Total Receipts'),
#    ('23_operating_expenditures', '23. Operating Expenditures'),
#    ('24_transfers_to_other_authorized_committees',
#     '24. Transfers to Other Authorized Committees'),
#    ('25_fundraising_disbursements', '25. Fundraising Disbursements'),
#    ('26_exempt_legal_and_accounting_disbursements',
#     '26. Exempt Legal and Accounting Disbursements'),
#    ('27_a_loan_repayments_by_candidate',
#     '27(a) Made or Guaranteed by the Candidate'),
#    ('27_b_loan_repayments_other', '27(b) Other Repayments'),
#    ('27_c_loan_repayments_total_made', '27(c) Total Loan Repayments Made'),
#    ('28_a_refunds_individuals', '28(a)  Individuals'),
#    ('28_b_refunds_parties', '28(b) Political Party Committees'),
#    ('28_c_refunds_pacs', '28(c) Other Political Committees'),
#    ('28_d_refunds_total', '28(d) Total Contributions Refunds'),
#    ('29_other_disbursements', '29. Other Disbursements'),
#    ('30_total_disbursements', '30. Total Disbursements'),
#    ('alabama', 'ALABAMA'),
#    ('alaska', 'ALASKA'),
#    ('arizona', 'ARIZONA'),
#    ('arkansas', 'ARKANSAS'),
#    ('california', 'CALIFORNIA'),
#    ('colorado', 'COLORADO'),
#    ('connecticut', 'CONNECTICUT'),
#    ('delaware', 'DELAWARE'),
#    ('dist_of_columbia', 'DIST OF COLUMBIA'),
#    ('florida', 'FLORIDA'),
#    ('georgia', 'GEORGIA'),
#    ('hawaii', 'HAWAII'),
#    ('idaho', 'IDAHO'),
#    ('illinois', 'ILLINOIS'),
#    ('indiana', 'INDIANA'),
#    ('iowa', 'IOWA'),
#    ('kansas', 'KANSAS'),
#    ('kentucky', 'KENTUCKY'),
#    ('louisiana', 'LOUISIANA'),
#    ('maine', 'MAINE'),
#    ('maryland', 'MARYLAND'),
#    ('massachusetts', 'MASSACHUSETTS'),
#    ('michigan', 'MICHIGAN'),
#    ('minnesota', 'MINNESOTA'),
#    ('mississippi', 'MISSISSIPPI'),
#    ('missouri', 'MISSOURI'),
#    ('montana', 'MONTANA'),
#    ('nebraska', 'NEBRASKA'),
#    ('nevada', 'NEVADA'),
#    ('new_hampshire', 'NEW HAMPSHIRE'),
#    ('new_jersey', 'NEW JERSEY'),
#    ('new_mexico', 'NEW MEXICO'),
#    ('new_york', 'NEW YORK'),
#    ('north_carolina', 'NORTH CAROLINA'),
#    ('north_dakota', 'NORTH DAKOTA'),
#    ('ohio', 'OHIO'),
#    ('oklahoma', 'OKLAHOMA'),
#    ('oregon', 'OREGON'),
#    ('pennsylvania', 'PENNSYLVANIA'),
#    ('rhode_island', 'RHODE ISLAND'),
#    ('south_carolina', 'SOUTH CAROLINA'),
#    ('south_dakota', 'SOUTH DAKOTA'),
#    ('tennessee', 'TENNESSEE'),
#    ('texas', 'TEXAS'),
#    ('utah', 'UTAH'),
#    ('vermont', 'VERMONT'),
#    ('virginia', 'VIRGINIA'),
#    ('washington', 'WASHINGTON'),
#    ('west_virginia', 'WEST VIRGINIA'),
#    ('wisconsin', 'WISCONSIN'),
#    ('wyoming', 'WYOMING'),
#    ('puerto_rico', 'PUERTO RICO'),
#    ('guam', 'GUAM'),
#    ('virgin_islands', 'VIRGIN ISLANDS'),
#    ('totals', 'TOTALS'),
#    ('date_general_election', 'Date - General Election'),
#    ('date_day_after_general_election', 'Date - Day after General Election')]},
#  'H4': {'^8.4|8.3|8.2|8.1|8.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'PAYEE STREET  1'),
#    ('payee_street_2', 'PAYEE STREET  2'),
#    ('payee_city', 'PAYEE CITY'),
#    ('payee_state', 'PAYEE STATE'),
#    ('payee_zip_code', 'PAYEE ZIP'),
#    ('account_identifier', 'ACCOUNT/EVENT IDENTIFIER'),
#    ('expenditure_date', 'EXPENDITURE DATE'),
#    ('total_amount', 'TOTAL FED-NONFED AMOUNT'),
#    ('federal_share', 'FEDERAL SHARE'),
#    ('nonfederal_share', 'NONFEDERAL SHARE'),
#    ('event_year_to_date', 'ACTIVITY/EVENT TOTAL YTD'),
#    ('expenditure_purpose_description', 'EXPENDITURE PURPOSE DESCRIP'),
#    ('category_code', 'CATEGORY CODE'),
#    ('administrative_voter_drive_activity',
#     'YES/NO  (Activity is Administrative - Only)'),
#    ('fundraising_activity', 'YES/NO  (Activity is Direct Fundraising)'),
#    ('exempt_activity', 'YES/NO  (Activity is an Exempt Activity)'),
#    ('generic_voter_drive_activity',
#     'YES/NO  (Activity is Generic Voter Drive - Only)'),
#    ('direct_candidate_support_activity',
#     'YES/NO  (Activity is Direct Candidate Support)'),
#    ('public_communications_party_activity',
#     'YES/NO  (Activity is Public Communications {Referring Only to Party} Made by PAC'),
#    ('memo_code', 'MEMO CODE'),
#    ('memo_text', 'MEMO TEXT/DESCRIPTION')],
#   '^7.0|6.4|6.3|6.2|6.1': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('transaction_id_number', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'PAYEE STREET  1'),
#    ('payee_street_2', 'PAYEE STREET  2'),
#    ('payee_city', 'PAYEE CITY'),
#    ('payee_state', 'PAYEE STATE'),
#    ('payee_zip_code', 'PAYEE ZIP'),
#    ('account_identifier', 'ACCOUNT/EVENT IDENTIFIER'),
#    ('expenditure_date', 'EXPENDITURE DATE'),
# ...
#    ('expenditure_amount', 'AMOUNT'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE'),
#    ('candidate_id_number', 'S/O FEC CAN ID NUMBER'),
#    ('candidate_name', 'S/O CAN/NAME'),
#    ('candidate_office', 'S/O CAN/OFFICE'),
#    ('candidate_state', 'S/O CAN/STATE'),
#    ('candidate_district', 'S/O CAN/DIST'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('transaction_id_number', 'TRAN ID'),
#    ('category_code', 'CATEGORY CODE'),
#    ('expenditure_purpose_code', 'TRANS {Purpose} CODE'),
#    ('calendar_y_t_d_per_election_office',
#     'Calendar YTD for election/office sought'),
#    ('election_code', 'ITEM ELECT CD'),
#    ('election_other_description', 'ITEM ELECT OTHER')],
#   '^3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_name', 'NAME (Payee)'),
#    ('payee_street_1', 'STREET  1'),
#    ('payee_street_2', 'STREET  2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('expenditure_purpose_descrip', 'TRANSDESC'),
#    ('dissemination_date', 'DATE (Of Expenditure)'),
#    ('expenditure_amount', 'AMOUNT'),
#    ('support_oppose_code', 'SUPPORT/OPPOSE'),
#    ('candidate_id_number', 'S/O FEC CAN ID NUMBER'),
#    ('candidate_name', 'S/O CAN/NAME'),
#    ('candidate_office', 'S/O CAN/OFFICE'),
#    ('candidate_state', 'S/O CAN/STATE'),
#    ('candidate_district', 'S/O CAN/DIST'),
#    ('conduit_name', 'CONDUIT NAME'),
#    ('conduit_street_1', 'CONDUIT STREET 1'),
#    ('conduit_street_2', 'CONDUIT STREET 2'),
#    ('conduit_city', 'CONDUIT CITY'),
#    ('conduit_state', 'CONDUIT STATE'),
#    ('conduit_zip_code', 'CONDUIT ZIP'),
#    ('amended_code', 'AMENDED CD')]},
#  'F94': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('candidate_id_number', 'CANDIDATE ID NUMBER'),
#    ('candidate_last_name', 'CANDIDATE LAST NAME'),
#    ('candidate_first_name', 'CANDIDATE FIRST NAME'),
#    ('candidate_middle_name', 'CANDIDATE MIDDLE NAME'),
#    ('candidate_prefix', 'CANDIDATE PREFIX'),
#    ('candidate_suffix', 'CANDIDATE SUFFIX'),
#    ('candidate_office', 'CANDIDATE OFFICE'),
#    ('candidate_state', 'CANDIDATE STATE'),
#    ('candidate_district', 'CANDIDATE DIST'),
#    ('election_code', 'ELECTION CODE'),
#    ('election_other_description', 'ELECTION OTHER DESCRIPTION')],
#   '^5.3|5.2|5.1|5.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('candidate_id_number', 'FEC CANDIDATE ID NUMBER'),
#    ('candidate_name', 'CANDIDATE NAME'),
#    ('candidate_office', 'CANDIDATE OFFICE'),
#    ('candidate_state', 'CANDIDATE STATE'),
#    ('candidate_district', 'CANDIDATE DIST'),
#    ('election_code', 'ELECTION CODE'),
#    ('election_other_description', 'ELECTION OTHER DESCRIPTION'),
#    ('transaction_id', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME')]},
#  'F3PZ2': {'^8.4|8.3|8.2': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('principal_committee_name', 'PRINCIPAL COMMITTEE NAME'),
#    ('coverage_from_date', 'COVERAGE FROM DATE'),
#    ('coverage_through_date', 'COVERAGE THROUGH DATE'),
#    ('col_a_cash_beginning_reporting_period',
#     '6 Cash on Hand at Beginning of Reporting Period'),
#    ('col_a_cash_on_hand_close',
#     '10 Cash on Hand at Close of Reporting Period'),
#    ('col_a_debts_to', '11 Debts and Obligations Owed TO the Committee'),
#    ('col_a_debts_by', '12 Debts and Obligations Owed BY the Committee'),
#    ('col_a_expenditures_subject_to_limits',
#     '13 Expenditures Subject to Limitation'),
#    ('col_a_net_contributions', '14 Net Contributions'),
#    ('col_a_net_operating_expenditures', '15 Net Operating Expenditures'),
#    ('col_a_federal_funds', '16 Federal Funds'),
#    ('col_a_individual_contributions',
#     '17(a)(iii) Contributions from Individuals/Persons Other Than Political Committees'),
#    ('col_a_political_party_contributions',
#     '17(b) Contributions from Political Party Committees'),
#    ('col_a_pac_contributions',
#     '17(c) Contributions from Other Political Committees'),
#    ('col_a_candidate_contributions', '17(d) Contributions from the Candidate'),
#    ('col_a_total_contributions', '17(e) Total Contributions'),
#    ('col_a_transfers_from_authorized',
#     '18 Transfers from Other Authorized Committees'),
#    ('col_a_candidate_loans',
#     '19(a) Loans Received From or Guaranteed by the Candidate'),
#    ('col_a_other_loans', '19(b) Other Loans'),
#    ('col_a_total_loans', '19(c) Total Loans'),
#    ('col_a_offset_to_operating_expenditures',
#     '20(a) Offsets to Operating Expenditures'),
#    ('col_a_offset_to_fundraising_expenditures',
#     '20(b) Offsets to Fundraising Expenditures'),
#    ('col_a_offset_to_legal_expenditures',
#     '20(c) Offsets to Legal and Accounting Expenditures'),
#    ('col_a_total_offset', '20(d) Total Offsets to Expenditures'),
#    ('col_a_other_receipts', '21 Other Receipts'),
#    ('col_a_total_receipts', '22 Total Receipts'),
#    ('col_a_operating_expenditures', '23 Operating Expenditures'),
#    ('col_a_transfers_to_authorized',
#     '24 Transfers to Other Authorized Committees'),
#    ('col_a_fundraising_disbursements', '25 Fundraising Disbursements'),
#    ('col_a_exempt_legal_disbursements',
#     '26 Exempt Legal and Accounting Disbursements'),
#    ('col_a_loan_repayments_by_candidate',
#     '27(a) Repayments of Loans Made or Guaranteed by Candidate'),
#    ('col_a_loan_repayments_other', '27(b) Other Loan Repayments'),
#    ('col_a_loan_repayments_total', '27(c) Total Loan Repayments Made'),
#    ('col_a_refunds_individuals',
#     '28(a) Refunds of Contributions from Individuals/Persons'),
#    ('col_a_refunds_parties',
#     '28(b) Refunds of Contributions from Political Party Committees'),
#    ('col_a_refunds_pacs',
#     '28(c) Refunds of Contributions from Other Political Committees'),
#    ('col_a_refunds_total', '28(d) Total Contributions Refunds'),
#    ('col_a_other_disbursements', '29 Other Disbursements'),
#    ('col_a_total_disbursements', '30 Total Disbursements'),
#    ('col_a_items_on_hand_to_be_liquidated',
#     '31 Items on Hand to be Liquidated')]},
#  'F91': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id', 'TRANSACTION ID NUMBER'),
#    ('controller_last_name', 'CONTROLLER LAST NAME (Share/Exer Control)'),
#    ('controller_first_name', 'CONTROLLER FIRST NAME'),
#    ('controller_middle_name', 'CONTROLLER MIDDLE NAME'),
#    ('controller_prefix', 'CONTROLLER PREFIX'),
#    ('controller_suffix', 'CONTROLLER SUFFIX'),
#    ('controller_street_1', 'CONTROLLER STREET 1'),
#    ('controller_street_2', 'CONTROLLER STREET 2'),
#    ('controller_city', 'CONTROLLER CITY'),
#    ('controller_state', 'CONTROLLER STATE'),
#    ('controller_zip_code', 'CONTROLLER ZIP'),
#    ('controller_employer', 'CONTROLLER EMPLOYER'),
#    ('controller_occupation', 'CONTROLLER OCCUPATION')],
#   '^5.3': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('controller_last_name', 'IND/NAME  (Share/Exer Control)'),
#    ('controller_street_1', 'STREET 1'),
#    ('controller_street_2', 'STREET 2'),
#    ('controller_city', 'CITY'),
#    ('controller_state', 'STATE'),
#    ('controller_zip_code', 'ZIP'),
#    ('controller_employer', 'EMPLOYER'),
#    ('controller_occupation', 'OCCUPATION'),
#    ('transaction_id', 'TRAN ID')],
#   '^5.2|5.1|5.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('controller_last_name', 'IND/NAME  (Share/Exer Control)'),
#    ('controller_street_1', 'STREET 1'),
#    ('controller_street_2', 'STREET 2'),
#    ('controller_city', 'CITY'),
#    ('controller_state', 'STATE'),
#    ('controller_zip_code', 'ZIP'),
#    ('controller_employer', 'EMPLOYER'),
#    ('controller_occupation', 'OCCUPATION'),
#    ('amended_cd', 'AMENDED CD'),
#    ('transaction_id', 'TRAN ID')]},
#  'F93': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'PAYEE ORGANIZATION NAME'),
#    ('payee_last_name', 'PAYEE LAST NAME'),
#    ('payee_first_name', 'PAYEE FIRST NAME'),
#    ('payee_middle_name', 'PAYEE MIDDLE NAME'),
#    ('payee_prefix', 'PAYEE PREFIX'),
#    ('payee_suffix', 'PAYEE SUFFIX'),
#    ('payee_street_1', 'DONOR STREET  1'),
#    ('payee_street_2', 'DONOR STREET  2'),
#    ('payee_city', 'DONOR CITY'),
#    ('payee_state', 'DONOR STATE'),
#    ('payee_zip_code', 'DONOR ZIP'),
#    ('election_code', 'ELECTION CODE'),
#    ('election_other_description', 'ELECTION OTHER DESCRIPTION'),
#    ('expenditure_date', 'EXPENDITURE DATE'),
#    ('expenditure_amount', 'EXPENDITURE AMOUNT'),
#    ('expenditure_purpose_descrip', 'EXPENDITURE PURPOSE DESCRIP'),
#    ('payee_employer', 'PAYEE EMPLOYER'),
#    ('payee_occupation', 'PAYEE OCCUPATION'),
#    ('communication_date', 'COMMUNICATION DATE')],
#   '^5.3|5.2': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_street_1', 'STREET  1'),
#    ('payee_street_2', 'STREET  2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('expenditure_purpose_code', 'TRANS {Purpose} CODE'),
#    ('expenditure_purpose_descrip', 'TRANS {Purpose} DESCRIP'),
#    ('election_code', 'ITEM ELECT CD'),
#    ('election_other_description', 'ITEM ELECT OTHER'),
#    ('expenditure_date', 'DATE OF EXPENDITURE'),
#    ('expenditure_amount', 'AMOUNT OF EXPENDITURE'),
#    ('transaction_id', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME'),
#    ('communication_date', 'COMMUNICATION DATE'),
#    ('payee_organization_name', 'RECIPIENT ORGANIZATION NAME'),
#    ('payee_last_name', 'RECIPIENT LAST NAME'),
#    ('payee_first_name', 'RECIPIENT FIRST NAME'),
#    ('payee_middle_name', 'RECIPIENT MIDDLE NAME'),
#    ('payee_prefix', 'RECIPIENT PREFIX'),
#    ('payee_suffix', 'RECIPIENT SUFFIX')],
#   '^5.1': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'RECIPIENT NAME'),
#    ('payee_street_1', 'STREET  1'),
#    ('payee_street_2', 'STREET  2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('expenditure_purpose_descrip', 'TRANS {Purpose} CODE'),
#    ('expenditure_purpose_code', 'TRANS {Purpose} DESCRIP'),
#    ('election_code', 'ITEM ELECT CD'),
#    ('election_other_description', 'ITEM ELECT OTHER'),
#    ('expenditure_date', 'DATE OF EXPENDITURE'),
#    ('expenditure_amount', 'AMOUNT OF EXPENDITURE'),
#    ('transaction_id', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME'),
#    ('communication_date', 'COMMUNICATION DATE'),
#    ('payee_last_name', 'RECIPIENT LAST NAME'),
#    ('payee_first_name', 'RECIPIENT FIRST NAME'),
#    ('payee_middle_name', 'RECIPIENT MIDDLE NAME'),
#    ('payee_prefix', 'RECIPIENT PREFIX'),
#    ('payee_suffix', 'RECIPIENT SUFFIX')],
#   '^5.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('payee_organization_name', 'CONTRIBUTOR NAME'),
#    ('payee_street_1', 'STREET  1'),
#    ('payee_street_2', 'STREET  2'),
#    ('payee_city', 'CITY'),
#    ('payee_state', 'STATE'),
#    ('payee_zip_code', 'ZIP'),
#    ('election_code', 'ITEM ELECT CD'),
#    ('election_other_description', 'ITEM ELECT OTHER'),
#    ('payee_employer', 'INDEMP'),
#    ('payee_occupation', 'INDOCC'),
#    ('expenditure_date', 'DATE RECEIVED'),
#    ('expenditure_amount', 'AMOUNT RECEIVED'),
#    ('expenditure_purpose_descrip', 'TRANS CODE'),
#    ('transaction_id', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME')]},
#  'F92': {'^8.4|8.3|8.2|8.1|8.0|7.0|6.4|6.3|6.2|6.1': [('form_type',
#     'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER COMMITTEE ID NUMBER'),
#    ('transaction_id', 'TRANSACTION ID NUMBER'),
#    ('back_reference_tran_id_number', 'BACK REFERENCE TRAN ID NUMBER'),
#    ('back_reference_sched_name', 'BACK REFERENCE SCHED NAME'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('contributor_organization_name', 'DONOR ORGANIZATION NAME'),
#    ('contributor_last_name', 'DONOR LAST NAME'),
#    ('contributor_first_name', 'DONOR FIRST NAME'),
#    ('contributor_middle_name', 'DONOR MIDDLE NAME'),
#    ('contributor_prefix', 'DONOR PREFIX'),
#    ('contributor_suffix', 'DONOR SUFFIX'),
#    ('contributor_street_1', 'DONOR STREET  1'),
#    ('contributor_street_2', 'DONOR STREET  2'),
#    ('contributor_city', 'DONOR CITY'),
#    ('contributor_state', 'DONOR STATE'),
#    ('contributor_zip_code', 'DONOR ZIP'),
#    ('contribution_date', 'DATE RECEIVED'),
#    ('contribution_amount', 'AMOUNT RECEIVED')],
#   '^5.3|5.2': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('contributor_organization_name', 'CONTRIBUTOR NAME'),
#    ('contributor_street_1', 'STREET  1'),
#    ('contributor_street_2', 'STREET  2'),
#    ('contributor_city', 'CITY'),
#    ('contributor_state', 'STATE'),
#    ('contributor_zip_code', 'ZIP'),
#    ('contributor_employer', 'INDEMP'),
#    ('contributor_occupation', 'INDOCC'),
#    ('contribution_date', 'DATE RECEIVED'),
#    ('contribution_amount', 'AMOUNT RECEIVED'),
#    ('transaction_type', 'TRANS CODE'),
#    ('transaction_id', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME')],
#   '^5.1': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('contributor_street_1', 'STREET  1'),
#    ('contributor_street_2', 'STREET  2'),
#    ('contributor_city', 'CITY'),
#    ('contributor_state', 'STATE'),
#    ('contributor_zip_code', 'ZIP'),
#    ('contributor_employer', 'INDEMP'),
#    ('contributor_occupation', 'INDOCC'),
#    ('contribution_date', 'DATE RECEIVED'),
#    ('contribution_amount', 'AMOUNT RECEIVED'),
#    ('transaction_type', 'TRANS CODE'),
#    ('transaction_id', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME'),
#    ('contributor_organization_name', 'CONTRIB ORGANIZATION NAME'),
#    ('contributor_last_name', 'CONTRIBUTOR LAST NAME'),
#    ('contributor_first_name', 'CONTRIBUTOR FIRST NAME'),
#    ('contributor_middle_name', 'CONTRIBUTOR MIDDLE NAME'),
#    ('contributor_prefix', 'CONTRIBUTOR PREFIX'),
#    ('contributor_suffix', 'CONTRIBUTOR SUFFIX')],
#   '^5.0': [('form_type', 'FORM TYPE'),
#    ('filer_committee_id_number', 'FILER FEC CMTE ID'),
#    ('entity_type', 'ENTITY TYPE'),
#    ('contributor_organization_name', 'CONTRIBUTOR NAME'),
#    ('contributor_street_1', 'STREET  1'),
#    ('contributor_street_2', 'STREET  2'),
#    ('contributor_city', 'CITY'),
#    ('contributor_state', 'STATE'),
#    ('contributor_zip_code', 'ZIP'),
#    ('contributor_employer', 'INDEMP'),
#    ('contributor_occupation', 'INDOCC'),
#    ('contribution_date', 'DATE RECEIVED'),
#    ('contribution_amount', 'AMOUNT RECEIVED'),
#    ('transaction_type', 'TRANS CODE'),
#    ('transaction_id', 'TRAN ID'),
#    ('back_reference_tran_id_number', 'BACK REF TRAN ID'),
#    ('back_reference_sched_name', 'BACK REF SCHED NAME')]}}

# %%
json.dump(form_name_to_schemas, open("form_schemas.json", "w"), indent=2)

# %%
# Now generate a rust file with the schemas
# in a lookup table

rust_path = Path("../crates/feco3/src/schemas.rs")
